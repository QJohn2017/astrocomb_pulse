# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import numpy as np

# %%
data = loadmat('smf_vs_edfa_data.mat')
shape = (len(np.unique(data['powers'])), len(np.unique(data['smfs'])))

smf = data['smfs'].reshape(*shape).T
power = data['powers'].reshape(*shape).T

fwhm = data['fwhms'].reshape(*shape).T
peaks = data['peaks'].reshape(*shape).T

# %%
# %matplotlib notebook

extent = [power.min(), power.max()+0.1, smf.min(), smf.max()+0.1]
plt.imshow(peaks, aspect='auto', origin='lower', extent=extent, cmap='inferno')
plt.xlabel('EDFA Power (W)')
plt.ylabel('SMF Compressor Length (m)')
plt.colorbar(label='Pulse Peak Power (pJ)')
plt.title('SMF 200m, HNLF 10m')
plt.savefig('edfa_vs_smf.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

plt.imshow(fwhm, aspect='auto', origin='lower', extent=extent, cmap='inferno')
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = loadmat('smf_vs_smf_data.mat')
shape = (len(np.unique(data['smf1s'])), len(np.unique(data['smf2s'])))

smf1 = data['smf1s'].reshape(*shape).T
smf2 = data['smf2s'].reshape(*shape).T

fwhm = data['fwhms'].reshape(*shape).T
peaks = data['peaks'].reshape(*shape).T

# %%
# %matplotlib notebook

plt.imshow(peaks, aspect='auto', origin='lower', extent=[160, 240, 0.5, 2.0], cmap='inferno')
plt.xlabel('SMF Length (m)')
plt.ylabel('Compressor SMF Length (m)')
plt.colorbar(label='Pulse Peak Power (pJ)')
plt.title('EDFA 3.5W, HNLF 10m')
plt.savefig('smf_vs_smf.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

plt.imshow(fwhm, aspect='auto', origin='lower', extent=[160, 240, 0.5, 2.0], cmap='inferno')
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
